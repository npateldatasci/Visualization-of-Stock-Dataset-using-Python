# %% [markdown]
# # Patel_Nirav_Midterm1
#
# ## Q1. You need to load the mentioned  .csv file as ticker variable.

# %%
#loading all the necessary libraries and giving aliases
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading all the tickers and csv files
AABA = pd.read_csv('AABA_2006-01-01_to_2018-01-01.csv')
AAPL = pd.read_csv('AAPL_2006-01-01_to_2018-01-01.csv')
AMZN = pd.read_csv('AMZN_2006-01-01_to_2018-01-01.csv')
AXP = pd.read_csv('AXP_2006-01-01_to_2018-01-01.csv')
BA = pd.read_csv('BA_2006-01-01_to_2018-01-01.csv')
CAT = pd.read_csv('CAT_2006-01-01_to_2018-01-01.csv')
CSCO = pd.read_csv('CSCO_2006-01-01_to_2018-01-01.csv')
CVX = pd.read_csv('CVX_2006-01-01_to_2018-01-01.csv')
DIS = pd.read_csv('DIS_2006-01-01_to_2018-01-01.csv')
GE = pd.read_csv('GE_2006-01-01_to_2018-01-01.csv')
GOOGL = pd.read_csv('GOOGL_2006-01-01_to_2018-01-01.csv')
GS = pd.read_csv('GS_2006-01-01_to_2018-01-01.csv')
HD = pd.read_csv('HD_2006-01-01_to_2018-01-01.csv')
IBM = pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv')
INTC = pd.read_csv('INTC_2006-01-01_to_2018-01-01.csv')
JNJ = pd.read_csv('JNJ_2006-01-01_to_2018-01-01.csv')
JPM = pd.read_csv('JPM_2006-01-01_to_2018-01-01.csv')
KO = pd.read_csv('KO_2006-01-01_to_2018-01-01.csv')
MCD = pd.read_csv('MCD_2006-01-01_to_2018-01-01.csv')
MMM = pd.read_csv('MMM_2006-01-01_to_2018-01-01.csv')
MRK = pd.read_csv('MRK_2006-01-01_to_2018-01-01.csv')
MSFT = pd.read_csv('MSFT_2006-01-01_to_2018-01-01.csv')
NKE = pd.read_csv('NKE_2006-01-01_to_2018-01-01.csv')
PFE = pd.read_csv('PFE_2006-01-01_to_2018-01-01.csv')
PG = pd.read_csv('PG_2006-01-01_to_2018-01-01.csv')
TRV = pd.read_csv('TRV_2006-01-01_to_2018-01-01.csv')
UNH = pd.read_csv('UNH_2006-01-01_to_2018-01-01.csv')
UTX = pd.read_csv('UTX_2006-01-01_to_2018-01-01.csv')
VZ = pd.read_csv('VZ_2006-01-01_to_2018-01-01.csv')
WMT = pd.read_csv('WMT_2006-01-01_to_2018-01-01.csv')
XOM = pd.read_csv('XOM_2006-01-01_to_2018-01-01.csv')

stocks_1718 = pd.read_csv('all_stocks_2017-01-01_to_2018-01-01.csv')
allsnp = pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv')

# %%
allsnp.head()
# Out:
#          Date   Open   High    Low  Close   Volume Name
# 0  2006-01-03  77.76  79.35  77.24  79.11  3117200  MMM
# 1  2006-01-04  79.49  79.49  78.25  78.71  2558000  MMM
# 2  2006-01-05  78.41  78.65  77.56  77.99  2529500  MMM
# 3  2006-01-06  78.64  78.90  77.64  78.63  2479500  MMM
# 4  2006-01-09  78.50  79.83  78.46  79.02  1845600  MMM

# %% [markdown]
# ## Q2.  Perform EDA for given stocks for different time periods.

# %%
# Information about the Dataset structure
allsnp.info()
allsnp.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93612 entries, 0 to 93611
# Data columns (total 7 columns):
# Date      93612 non-null object
# Open      93587 non-null float64
# High      93602 non-null float64
# Low       93592 non-null float64
# Close     93612 non-null float64
# Volume    93612 non-null int64
# Name      93612 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.0+ MB
#                Open          High           Low         Close        Volume
# count  93587.000000  93602.000000  93592.000000  93612.000000  9.361200e+04
# mean      85.623260     86.387045     84.836664     85.641753  2.015667e+07
# std      108.151723    108.956365    107.225361    108.121106  3.442108e+07
# min        6.750000      7.170000      0.000000      6.660000  0.000000e+00
# 25%       33.950000     34.290000     33.600000     33.960000  5.040180e+06
# 50%       60.040000     60.630000     59.490000     60.050000  9.701142e+06
# ...

# %%
# Number of Null Values in the data
null_columns=allsnp.columns[allsnp.isnull().any()]
allsnp[null_columns].isnull().sum()
# Out:
# Open    25
# High    10
# Low     20
# dtype: int64

# %%
# Removing all the NUll Values from the data
allsnp.dropna().head()
# Out:
#          Date   Open   High    Low  Close   Volume Name
# 0  2006-01-03  77.76  79.35  77.24  79.11  3117200  MMM
# 1  2006-01-04  79.49  79.49  78.25  78.71  2558000  MMM
# 2  2006-01-05  78.41  78.65  77.56  77.99  2529500  MMM
# 3  2006-01-06  78.64  78.90  77.64  78.63  2479500  MMM
# 4  2006-01-09  78.50  79.83  78.46  79.02  1845600  MMM

# %%
# Defining a new variable called as Gain, which is obtained by deducting everyday opening price from the closing price (Close - Open).
allsnp['Gain'] = allsnp['Close'] - allsnp['Open']
allsnp.head()
# Out:
#          Date   Open   High    Low  Close   Volume Name  Gain
# 0  2006-01-03  77.76  79.35  77.24  79.11  3117200  MMM  1.35
# 1  2006-01-04  79.49  79.49  78.25  78.71  2558000  MMM -0.78
# 2  2006-01-05  78.41  78.65  77.56  77.99  2529500  MMM -0.42
# 3  2006-01-06  78.64  78.90  77.64  78.63  2479500  MMM -0.01
# 4  2006-01-09  78.50  79.83  78.46  79.02  1845600  MMM  0.52

# %%
# Looking at the average(mean) price values for different variables for each stock, starting with the highest at the top.
AvgPrices = allsnp.groupby(['Name']).mean().sort_values(by='Close',ascending=False).head()
AvgPrices
# Out:
#              Open        High         Low       Close        Volume      Gain
# Name
# GOOGL  428.200802  431.835618  424.130275  428.044001  3.551504e+06 -0.156800
# AMZN   299.335310  302.371163  296.037695  299.376231  5.931712e+06  0.040921
# GS     165.567890  167.545325  163.600901  165.611437  7.175135e+06  0.023766
# IBM    145.515545  146.681738  144.471597  145.617278  5.773301e+06  0.102047
# MMM    111.776588  112.615732  110.986366  111.861844  3.342332e+06  0.055674

# %%
# Looking at the average(mean) price values for different variables for each stock, starting with the lowest at the top.
AvgPrices = allsnp.groupby(['Name']).mean().sort_values(by='Close').head()
AvgPrices
# Out:
#            Open       High        Low      Close        Volume      Gain
# Name
# CSCO  24.031736  24.277714  23.793014  24.039632  4.440027e+07  0.007897
# GE    25.132955  25.352649  24.891130  25.122232  5.367835e+07 -0.010884
# INTC  25.396744  25.659096  25.142136  25.407890  4.919834e+07  0.011146
# PFE   25.437350  25.655230  25.223286  25.442477  3.792700e+07  0.002570
# AABA  28.426479  28.766532  28.066558  28.412726  2.158391e+07 -0.013753

# %% [markdown]
# ## Splitting Data into two time periods for analysis purpose
# ### Group1(stocks06) with data for years 2006, 2007 and 2008, and Group2(stocks17) consist of data for years 2015, 2016 and 2017

# %%
#Creating variable stocks06 for data for group1: years-2006, 2007 and 2008
stocks06=allsnp[(allsnp['Date'] > '2005-12-31') & (allsnp['Date'] < '2009-01-01')]
#Creating variable stock17 for data for group2: years-2015, 2016 and 2017
stocks17=allsnp[(allsnp['Date'] > '2014-12-31') & (allsnp['Date'] < '2018-01-01')]

# %% [markdown]
# ## Performing EDA for Group1(stocks06)

# %%
#Looking at volume of different stocks in this group
Avgvol = stocks06[["Volume","Name"]].groupby(["Name"]).agg({'Volume':['mean']})
fig=Avgvol.plot(kind='bar',fontsize=15,figsize=(30,10),legend=True)
fig.legend(loc=1,fontsize=20)
plt.xlabel('Name of Stock',fontsize=20)
plt.ylabel('Average Volume',fontsize=20)
plt.title('Average Stock Volume 2006-08',fontsize=20)
plt.show()

# %%
#Looking at closing price of different stocks in this group
Avgclose = stocks06[["Close","Name"]].groupby(["Name"]).agg({'Close':['mean']})
fig=Avgclose.plot(kind='bar',fontsize=20,figsize=(30,10),legend=True)
fig.legend(loc=1,fontsize=18)
plt.xlabel('Name of Stock',fontsize=20)
plt.ylabel('Average Closing',fontsize=20)
plt.title('Average Stock Closing Price 2006-08',fontsize=20)
plt.show()

# %%
#Who are the top ganiners in this group
Topgain06 = stocks06[["Gain","Name","Close","Open","High","Low","Volume"]].groupby(["Name"]).max().sort_values(by='Gain',ascending=False).head(10)
Topgain06
# Out:
#         Gain   Close    Open    High     Low     Volume
# Name
# GS     17.01  247.92  243.55  250.70  240.00  114590630
# GOOGL  14.87  371.27  370.94  373.99  362.86   41182889
# CVX     9.72  103.09  103.25  104.63  102.69   48214154
# AMZN    8.79  100.82   96.59  101.09   94.75  104404589
# XOM     8.18   95.05   95.08   96.12   94.46  112904817
# JPM     7.69   53.20   52.83   53.25   52.59  194090479
# IBM     6.47  130.00  129.83  130.93  128.80   30774276
# TRV     5.80   56.76   56.99   58.57   56.23   14077928
# UNH     5.32   62.90   62.90   62.93   62.03   51416207
# MMM     5.20   95.85   96.10   97.00   95.12   24360500

# %%
#Who are the top loser in thi group
Toploser06 = stocks06[["Gain","Name","Close","Open","High","Low","Volume"]].groupby(["Name"]).max().sort_values(by='Gain').head(10)
Toploser06
# Out:
#       Gain  Close   Open   High    Low     Volume
# Name
# PFE   1.25  28.47  28.47  28.60  28.25  289340500
# NKE   1.33  17.52  17.34  17.65  17.00   78979200
# CSCO  1.55  34.08  34.04  34.24  33.41  248593192
# INTC  1.65  27.98  27.79  27.99  27.57  310073444
# AAPL  1.86  28.55  28.66  28.99  28.26  843264044
# KO    1.91  32.78  32.69  32.80  32.36   79214586
# AABA  2.03  43.42  43.10  43.66  42.82  438231658
# MSFT  2.64  37.06  37.22  37.50  36.63  591078581
# MRK   2.79  60.77  61.00  61.62  60.13   78525400
# GE    2.89  42.12  42.03  42.15  41.80  519847777

# %%
# looking at overall trend by closing price in this group
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd
fig,axes=plt.subplots(figsize=(30,12))
stocks06[stocks06['Name']=='CAT'].plot(x='Date',y='Close',label='Catterpillar',ax=axes)
stocks06[stocks06['Name']=='GOOGL'].plot(x='Date',y='Close',label='Google',ax=axes)
stocks06[stocks06['Name']=='BA'].plot(x='Date',y='Close',label='Boeing',ax=axes)
stocks06[stocks06['Name']=='UNH'].plot(x='Date',y='Close',label='UnitedHealth Group Inc',ax=axes)
stocks06[stocks06['Name']=='GS'].plot(x='Date',y='Close',label='Goldman Sachs Group Inc',ax=axes)
stocks06[stocks06['Name']=='MMM'].plot(x='Date',y='Close',label='3M',ax=axes)
stocks06[stocks06['Name']=='XOM'].plot(x='Date',y='Close',label='Exxon Mobil Corporation',ax=axes)
stocks06[stocks06['Name']=='AXP'].plot(x='Date',y='Close',label='American Express Company',ax=axes)
stocks06[stocks06['Name']=='WMT'].plot(x='Date',y='Close',label='Walmart Inc',ax=axes)
stocks06[stocks06['Name']=='HD'].plot(x='Date',y='Close',label='Home Depot Inc',ax=axes)
axes.set_ylabel("Close")
axes.set_title("Closing_High",fontsize=20)
# Out:
# Text(0.5,1,'Closing_High')

# %% [markdown]
# ### Performing EDA on Group2 (stocks17) data

# %%
#looking at volume in this group
Avgvol = stocks17[["Volume","Name"]].groupby(["Name"]).agg({'Volume':['mean']})
fig=Avgvol.plot(kind='bar',fontsize=15,figsize=(30,10),legend=True)
fig.legend(loc=1,fontsize=20)
plt.xlabel('Name of Stock',fontsize=20)
plt.ylabel('Average Volume',fontsize=20)
plt.title('Average Stock Volume 2015-17',fontsize=20)
plt.show()

# %%
#looking at closing price in this group
Avgclose = stocks17[["Close","Name"]].groupby(["Name"]).agg({'Close':['mean']})
fig=Avgclose.plot(kind='bar',fontsize=20,figsize=(30,10),legend=True)
fig.legend(loc=1,fontsize=18)
plt.xlabel('Name of Stock',fontsize=20)
plt.ylabel('Average Closing',fontsize=20)
plt.title('Average Stock Closing Price 2015-17',fontsize=20)
plt.show()

# %%
#Top gainers in this group
Topgain17 = stocks17[["Gain","Name","Close","Open","High","Low","Volume"]].groupby(["Name"]).max().sort_values(by='Gain',ascending=False).head(10)
Topgain17
# Out:
#         Gain    Close     Open     High      Low     Volume
# Name
# AMZN   42.81  1195.83  1204.88  1213.41  1191.15   23856060
# GOOGL  20.87  1085.09  1083.02  1086.49  1072.27   12858136
# BA      9.97   297.90   298.70   299.33   297.11   33695573
# AAPL    8.25   176.42   175.11   177.20   174.86  161454199
# GS      8.23   261.01   261.66   262.14   259.16   12464020
# UNH     7.09   228.17   229.26   231.77   222.29   16358215
# MMM     5.65   243.14   243.19   244.23   239.15    8645905
# HD      5.07   190.36   190.91   191.49   190.01   18264081
# TRV     5.05   136.36   136.45   137.95   135.81    5704560
# IBM     5.01   181.95   182.00   182.79   180.92   30490192

# %%
#Top loser in the group
Toploser17 = stocks17[["Gain","Name","Close","Open","High","Low","Volume"]].groupby(["Name"]).max().sort_values(by='Gain').head(10)
Toploser17
# Out:
#       Gain  Close   Open   High    Low     Volume
# Name
# CSCO  0.95  38.74  38.88  39.00  38.49  117439078
# KO    1.19  47.43  47.32  47.48  46.78   43576384
# PFE   1.39  37.31  37.22  37.39  37.06  284427797
# VZ    1.55  56.53  56.32  56.95  56.32   47425433
# GE    1.69  32.93  32.96  33.00  32.74  430949788
# INTC  1.99  47.56  47.54  47.64  46.66  107402364
# MRK   2.04  66.58  66.38  66.80  66.00   72875999
# MSFT  2.21  86.85  87.12  87.50  86.23  169163953
# AABA  2.29  72.93  73.02  73.25  72.46  269377149
# PG    2.33  94.40  94.17  94.67  93.83  123735748

# %%
# looking at overall trend on top gainers in this group
fig,axes=plt.subplots(figsize=(30,12))
stocks17[stocks17['Name']=='AMZN'].plot(x='Date',y='Close',label='Amazon',ax=axes)
stocks17[stocks17['Name']=='GOOGL'].plot(x='Date',y='Close',label='Google',ax=axes)
stocks17[stocks17['Name']=='BA'].plot(x='Date',y='Close',label='Boeing',ax=axes)
stocks17[stocks17['Name']=='UNH'].plot(x='Date',y='Close',label='UnitedHealth Group Inc',ax=axes)
stocks17[stocks17['Name']=='GS'].plot(x='Date',y='Close',label='Goldman Sachs Group Inc',ax=axes)
stocks17[stocks17['Name']=='MMM'].plot(x='Date',y='Close',label='3M',ax=axes)
stocks17[stocks17['Name']=='TRV'].plot(x='Date',y='Close',label='Travelers Companies Inc',ax=axes)
stocks17[stocks17['Name']=='IBM'].plot(x='Date',y='Close',label='IBM',ax=axes)
stocks17[stocks17['Name']=='WMT'].plot(x='Date',y='Close',label='Walmart Inc',ax=axes)
stocks17[stocks17['Name']=='HD'].plot(x='Date',y='Close',label='Home Depot Inc',ax=axes)
axes.set_ylabel("Close")
axes.set_title("Closing_High",fontsize=20)
# Out:
# Text(0.5,1,'Closing_High')

# %% [markdown]
# # Q3. Perform descriptive analysis for any two stock from given dataset and compare the analysis.

# %%
# Amazon and google were choosen for this part
Q3Stocks=allsnp[allsnp['Name'].isin(['AMZN','GOOGL'])].reset_index(drop=True)
Q3Stocks.head()
# Out:
#          Date    Open    High     Low   Close    Volume   Name  Gain
# 0  2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL  6.36
# 1  2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL  0.67
# 2  2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL  2.63
# 3  2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL  4.40
# 4  2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL  0.24

# %%
#information about this group
Q3Stocks.info()
Q3Stocks.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6038 entries, 0 to 6037
# Data columns (total 8 columns):
# Date      6038 non-null object
# Open      6038 non-null float64
# High      6038 non-null float64
# Low       6038 non-null float64
# Close     6038 non-null float64
# Volume    6038 non-null int64
# Name      6038 non-null object
# Gain      6038 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 377.5+ KB
#               Open        High          Low        Close        Volume  \
# count  6038.000000  6038.00000  6038.000000  6038.000000  6.038000e+03
# mean    363.768056   367.10339   360.083985   363.710116  4.741608e+06
# std     267.017752   268.51303   265.156497   266.930561  4.375820e+06
# min      26.090000    26.30000    25.760000    26.070000  5.211410e+05
# 25%     184.212500   186.50750   181.812500   184.435000  2.251445e+06
# 50%     281.420000   284.51500   278.680000   281.515000  3.605167e+06
# ...

# %%
# get min for amazon
Q3Stocks_AMZN = Q3Stocks[(Q3Stocks['Name'] == 'AMZN')]
Q3Stocks_AMZN = Q3Stocks_AMZN.sort_values(by='Low').head(5).reset_index()
Q3Stocks_AMZN = Q3Stocks_AMZN[Q3Stocks_AMZN.columns[1:9]] 
Q3Stocks_AMZN
# Out:
#          Date   Open   High    Low  Close    Volume  Name  Gain
# 0  2006-08-11  26.43  26.43  25.76  26.07   5115908  AMZN -0.36
# 1  2006-08-01  26.55  26.64  25.84  26.32  13562592  AMZN -0.23
# 2  2006-08-10  26.20  26.52  25.88  26.49   6405609  AMZN  0.29
# 3  2006-08-02  26.15  26.30  25.89  26.09   7813074  AMZN -0.06
# 4  2006-08-03  26.09  26.90  25.90  26.69   6943928  AMZN  0.60

# %%
# ge max for amazon
Q3Stocks_AMZN = Q3Stocks[(Q3Stocks['Name'] == 'AMZN')]
Q3Stocks_AMZN = Q3Stocks_AMZN.sort_values(by='High',ascending=False).head(5).reset_index()
Q3Stocks_AMZN = Q3Stocks_AMZN[Q3Stocks_AMZN.columns[1:9]] 
Q3Stocks_AMZN
# Out:
#          Date     Open     High      Low    Close   Volume  Name   Gain
# 0  2017-11-27  1202.66  1213.41  1191.15  1195.83  6744045  AMZN  -6.83
# 1  2017-11-28  1204.88  1205.34  1188.52  1193.60  4559449  AMZN -11.28
# 2  2017-11-29  1194.80  1194.80  1145.19  1161.27  9257512  AMZN -33.53
# 3  2017-12-18  1187.37  1194.78  1180.91  1190.58  2947625  AMZN   3.21
# 4  2017-12-19  1189.15  1192.97  1179.14  1187.38  2587792  AMZN  -1.77

# %%
# get min for google
Q3Stocks_GOOGL = Q3Stocks[(Q3Stocks['Name'] == 'GOOGL')]
Q3Stocks_GOOGL = Q3Stocks_GOOGL.sort_values(by='Low').head(5).reset_index()
Q3Stocks_GOOGL = Q3Stocks_GOOGL[Q3Stocks_GOOGL.columns[1:9]] 
Q3Stocks_GOOGL
# Out:
#          Date    Open    High     Low   Close    Volume   Name  Gain
# 0  2008-11-21  131.39  134.82  123.77  131.35  10246338  GOOGL -0.04
# 1  2008-11-24  134.76  135.11  124.63  128.85  10059557  GOOGL -5.91
# 2  2008-11-20  137.58  141.61  129.65  129.91   9780746  GOOGL -7.67
# 3  2008-12-02  135.00  139.03  131.42  137.69   5841927  GOOGL  2.69
# 4  2008-12-05  135.65  142.26  132.14  142.14   6523993  GOOGL  6.49

# %%
# get max for google
Q3Stocks_GOOGL = Q3Stocks[(Q3Stocks['Name'] == 'GOOGL')]
Q3Stocks_GOOGL = Q3Stocks_GOOGL.sort_values(by='High',ascending=False).head(5).reset_index()
Q3Stocks_GOOGL = Q3Stocks_GOOGL[Q3Stocks_GOOGL.columns[1:9]] 
Q3Stocks_GOOGL
# Out:
#          Date     Open     High      Low    Close   Volume   Name   Gain
# 0  2017-12-18  1076.45  1086.49  1070.37  1085.09  1514601  GOOGL   8.64
# 1  2017-12-19  1083.02  1084.98  1072.27  1079.78  1317519  GOOGL  -3.24
# 2  2017-12-20  1080.92  1081.24  1068.60  1073.56  1436391  GOOGL  -7.36
# 3  2017-11-28  1073.99  1080.00  1054.54  1063.29  1821171  GOOGL -10.70
# 4  2017-12-21  1075.39  1077.52  1069.00  1070.85  1282025  GOOGL  -4.54

# %%
#getting min overall
Q3Stocks_min = Q3Stocks.sort_values(by='Low').head(5).reset_index()
Q3Stocks_min
# Out:
#    index        Date   Open   High    Low  Close    Volume  Name  Gain
# 0   3172  2006-08-11  26.43  26.43  25.76  26.07   5115908  AMZN -0.36
# 1   3164  2006-08-01  26.55  26.64  25.84  26.32  13562592  AMZN -0.23
# 2   3171  2006-08-10  26.20  26.52  25.88  26.49   6405609  AMZN  0.29
# 3   3165  2006-08-02  26.15  26.30  25.89  26.09   7813074  AMZN -0.06
# 4   3166  2006-08-03  26.09  26.90  25.90  26.69   6943928  AMZN  0.60

# %%
# get max overall
Q3Stocks_max = Q3Stocks.sort_values(by='High',ascending=False).head(5).reset_index()
Q3Stocks_max
# Out:
#    index        Date     Open     High      Low    Close   Volume  Name   Gain
# 0   6014  2017-11-27  1202.66  1213.41  1191.15  1195.83  6744045  AMZN  -6.83
# 1   6015  2017-11-28  1204.88  1205.34  1188.52  1193.60  4559449  AMZN -11.28
# 2   6016  2017-11-29  1194.80  1194.80  1145.19  1161.27  9257512  AMZN -33.53
# 3   6029  2017-12-18  1187.37  1194.78  1180.91  1190.58  2947625  AMZN   3.21
# 4   6030  2017-12-19  1189.15  1192.97  1179.14  1187.38  2587792  AMZN  -1.77

# %%
# Amazon and Google further analysis(correlation study )
sns.pairplot(Q3Stocks)

# %%
AMZN['Volume'] = AMZN['Volume']/10000000 
GOOGL['Volume'] = GOOGL['Volume']/10000000

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
AMZN.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
AMZN.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
GOOGL.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
GOOGL.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
#basic stock Volume movement for Amazon and Google
fig,axes=plt.subplots(figsize=(30,8))
Q3Stocks[Q3Stocks['Name']=='AMZN'].plot(x='Date',y='Close',label='AMZN',ax=axes)
Q3Stocks[Q3Stocks['Name']=='GOOGL'].plot(x='Date',y='Close',label='Google',ax=axes)
axes.set_ylabel("Close")
axes.set_title("Stock Close",fontsize=20)
# Out:
# Text(0.5,1,'Stock Close')

# %%
#basic stock Volume movement for Amazon and Google
fig,axes=plt.subplots(figsize=(30,8))
Q3Stocks[Q3Stocks['Name']=='AMZN'].plot(x='Date',y='Volume',label='Amazon',ax=axes)
Q3Stocks[Q3Stocks['Name']=='GOOGL'].plot(x='Date',y='Volume',label='Google',ax=axes)
axes.set_ylabel("Stock Volume")
axes.set_title("Stock volume movement",fontsize=20)
# Out:
# Text(0.5,1,'Stock volume movement')

# %%
#monthly closing price distribution

Q3Stocks['Month']=pd.to_datetime(allsnp['Date']).dt.month
plt.style.use('bmh')
fig,axes=plt.subplots(2,1,figsize=(25,15),sharex=True)

sns.boxplot(ax=axes[0],x='Month',y='Gain',data=Q3Stocks[Q3Stocks['Name']=='GOOGL'],palette='husl')
sns.boxplot(ax=axes[1],x='Month',y='Gain',data=Q3Stocks[Q3Stocks['Name']=='AMZN'],palette='husl')

plt.suptitle("Gain Price Monthwise",fontsize=26)

axes[0].set_title("Google",fontsize=18)
axes[1].set_title('Amazon',fontsize=18)


axes[0].set_ylabel("Gain",fontsize=18)
axes[1].set_ylabel("Gain",fontsize=18)
# Out:
# Text(0,0.5,'Gain')

# %%
allsnp = pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv')

plt.style.use('bmh')
Q3Stocks['15d']= Q3Stocks.groupby("Name")['High'].rolling(15).mean().reset_index(drop=True)
fig,axes=plt.subplots(1,2,figsize=(30,8))
Q3Stocks[Q3Stocks['Name']=='AMZN'].plot(x='Date',y='15d',label='Moving Average',ax=axes[0])
Q3Stocks[Q3Stocks['Name']=='GOOGL'].plot(x='Date',y='15d',label='Moving Average',ax=axes[1])

plt.suptitle("Moving Average plot with 15 day window",fontsize=18)

axes[0].set_ylabel("Highest Price",fontsize=18)
axes[0].set_title('Amazon',fontsize=18)
axes[1].set_title('Google',fontsize=18)

plt.tight_layout()
fig.subplots_adjust(top=0.8)

# %% [markdown]
# # Q4. Take five stocks of your choice and create the same type of report stated in question 3.

# %%
#choosing Goldman sachs,IBM, 3M, Boeing and Chevron corp for this part
Q4Stocks=allsnp[allsnp['Name'].isin(['GS','IBM','MMM','BA','CVX'])].reset_index(drop=True)
Q4Stocks.head(1500)
# Out:
#             Date   Open   High    Low  Close   Volume Name  Gain
# 0     2006-01-03  77.76  79.35  77.24  79.11  3117200  MMM  1.35
# 1     2006-01-04  79.49  79.49  78.25  78.71  2558000  MMM -0.78
# 2     2006-01-05  78.41  78.65  77.56  77.99  2529500  MMM -0.42
# 3     2006-01-06  78.64  78.90  77.64  78.63  2479500  MMM -0.01
# 4     2006-01-09  78.50  79.83  78.46  79.02  1845600  MMM  0.52
# 5     2006-01-10  79.00  79.01  78.08  78.53  1919900  MMM -0.47
# 6     2006-01-11  78.44  78.66  77.84  78.37  1911900  MMM -0.07
# 7     2006-01-12  78.20  78.23  77.20  77.70  2121100  MMM -0.50
# 8     2006-01-13  76.95  78.20  76.95  77.50  1925300  MMM  0.55
# 9     2006-01-17  77.10  77.62  77.00  77.09  2073400  MMM -0.01
# 10    2006-01-18  77.00  77.28  76.52  76.99  1838400  MMM -0.01
# 11    2006-01-19  77.19  77.37  76.70  76.91  1807100  MMM -0.28
# 12    2006-01-20  76.91  76.91  75.18  75.24  3286900  MMM -1.67
# ...

# %%
Q4Stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15100 entries, 0 to 15099
# Data columns (total 8 columns):
# Date      15100 non-null object
# Open      15095 non-null float64
# High      15099 non-null float64
# Low       15095 non-null float64
# Close     15100 non-null float64
# Volume    15100 non-null int64
# Name      15100 non-null object
# Gain      15095 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 943.8+ KB

# %%
Q4Stocks.describe()
# Out:
#                Open         High           Low         Close        Volume  \
# count  15095.000000  15099.00000  15095.000000  15100.000000  1.510000e+04
# mean     123.786348    124.93245    122.655534    123.846336  6.067025e+06
# std       47.480581     47.77664     47.208291     47.502961  4.844497e+06
# min       29.220000     30.02000     29.050000     29.360000  8.708300e+04
# 25%       83.490000     84.44500     82.605000     83.577500  3.192257e+06
# 50%      116.440000    117.58000    115.500000    116.550000  4.760299e+06
# 75%      159.745000    160.86000    158.390000    159.772500  7.404898e+06
# max      298.700000    299.33000    297.110000    297.900000  1.145906e+08
#
#                Gain
# count  15095.000000
# mean       0.039876
# std        1.893437
# min     -110.480000
# 25%       -0.700000
# 50%        0.060000
# 75%        0.820000
# max       17.010000

# %%
Q4Stocks_BA = Q4Stocks[(Q4Stocks['Name'] == 'BA')]
Q4Stocks_BA = Q4Stocks_BA.sort_values(by='Low').head(1).reset_index()
Q4Stocks_BA = Q4Stocks_BA[Q4Stocks_BA.columns[1:9]] 
Q4Stocks_BA
# Out:
#          Date  Open   High    Low  Close    Volume Name  Gain
# 0  2009-03-03  29.7  30.11  29.05  29.36  10434638   BA -0.34

# %%
Q4Stocks_BA = Q4Stocks[(Q4Stocks['Name'] == 'BA')]
Q4Stocks_BA = Q4Stocks_BA.sort_values(by='High',ascending=False).head(1).reset_index()
Q4Stocks_BA = Q4Stocks_BA[Q4Stocks_BA.columns[1:9]] 
Q4Stocks_BA
# Out:
#          Date   Open    High     Low  Close   Volume Name  Gain
# 0  2017-12-20  298.7  299.33  297.11  297.9  2533689   BA  -0.8

# %%
# get min and max for q4
Q4Stocks_GS = Q4Stocks[(Q4Stocks['Name'] == 'GS')]
Q4Stocks_GS = Q4Stocks_GS.sort_values(by='Low').head(1).reset_index()
Q4Stocks_GS = Q4Stocks_GS[Q4Stocks_GS.columns[1:9]] 
Q4Stocks_GS
# Out:
#          Date   Open   High    Low  Close    Volume Name  Gain
# 0  2008-11-21  54.54  54.54  47.41  53.31  39597150   GS -1.23

# %%
Q4Stocks_GS = Q4Stocks[(Q4Stocks['Name'] == 'GS')]
Q4Stocks_GS = Q4Stocks_GS.sort_values(by='High',ascending=False).head(1).reset_index()
Q4Stocks_GS = Q4Stocks_GS[Q4Stocks_GS.columns[1:9]] 
Q4Stocks_GS
# Out:
#          Date    Open    High     Low   Close   Volume Name  Gain
# 0  2017-12-22  261.66  262.14  257.72  258.97  2100623   GS -2.69

# %%
Q4Stocks_IBM = Q4Stocks[(Q4Stocks['Name'] == 'IBM')]
Q4Stocks_IBM = Q4Stocks_IBM.sort_values(by='Low').head(1).reset_index()
Q4Stocks_IBM = Q4Stocks_IBM[Q4Stocks_IBM.columns[1:9]] 
Q4Stocks_IBM
# Out:
#          Date   Open   High   Low  Close    Volume Name  Gain
# 0  2008-11-21  72.74  76.98  69.5  74.88  19804617  IBM  2.14

# %%
Q4Stocks_IBM = Q4Stocks[(Q4Stocks['Name'] == 'IBM')]
Q4Stocks_IBM = Q4Stocks_IBM.sort_values(by='High',ascending=False).head(1).reset_index()
Q4Stocks_IBM = Q4Stocks_IBM[Q4Stocks_IBM.columns[1:9]] 
Q4Stocks_IBM
# Out:
#          Date    Open   High     Low   Close   Volume Name  Gain
# 0  2013-03-15  215.38  215.9  213.41  214.92  7937244  IBM -0.46

# %%
Q4Stocks_IBM = Q4Stocks[(Q4Stocks['Name'] == 'IBM')]
Q4Stocks_IBM = Q4Stocks_IBM.sort_values(by='Low').head(1).reset_index()
Q4Stocks_IBM = Q4Stocks_IBM[Q4Stocks_IBM.columns[1:9]] 
Q4Stocks_IBM

# %%
Q4Stocks_MMM = Q4Stocks[(Q4Stocks['Name'] == 'MMM')]
Q4Stocks_MMM = Q4Stocks_MMM.sort_values(by='Low').head(1).reset_index()
Q4Stocks_MMM = Q4Stocks_MMM[Q4Stocks_MMM.columns[1:9]] 
Q4Stocks_MMM
# Out:
#          Date   Open   High    Low  Close   Volume Name  Gain
# 0  2009-03-06  42.84  43.28  40.87  41.83  9174759  MMM -1.01

# %%
Q4Stocks_MMM = Q4Stocks[(Q4Stocks['Name'] == 'MMM')]
Q4Stocks_MMM = Q4Stocks_MMM.sort_values(by='High',ascending=False).head(1).reset_index()
Q4Stocks_MMM = Q4Stocks_MMM[Q4Stocks_MMM.columns[1:9]] 
Q4Stocks_MMM
# Out:
#          Date    Open    High     Low   Close   Volume Name  Gain
# 0  2017-12-04  243.05  244.23  238.51  239.26  2468747  MMM -3.79

# %%
Q4Stocks_CVX = Q4Stocks[(Q4Stocks['Name'] == 'CVX')]
Q4Stocks_CVX = Q4Stocks_CVX.sort_values(by='Low').head(1).reset_index()
Q4Stocks_CVX = Q4Stocks_CVX[Q4Stocks_CVX.columns[1:9]] 
Q4Stocks_CVX
# Out:
#          Date   Open  High    Low  Close    Volume Name  Gain
# 0  2006-03-10  54.15  54.6  53.76  54.08  11114400  CVX -0.07

# %%
Q4Stocks_CVX = Q4Stocks[(Q4Stocks['Name'] == 'CVX')]
Q4Stocks_CVX = Q4Stocks_CVX.sort_values(by='High',ascending=False).head(1).reset_index()
Q4Stocks_CVX = Q4Stocks_CVX[Q4Stocks_CVX.columns[1:9]] 
Q4Stocks_CVX
# Out:
#          Date    Open   High     Low   Close   Volume Name  Gain
# 0  2014-07-24  134.03  135.1  133.69  134.85  5340621  CVX  0.82

# %%
Q4Stocks_min = Q4Stocks.sort_values(by='Low').head(5).reset_index()
Q4Stocks_min
# Out:
#    index        Date   Open   High    Low  Close    Volume Name  Gain
# 0   3815  2009-03-03  29.70  30.11  29.05  29.36  10434638   BA -0.34
# 1   3817  2009-03-05  29.22  30.02  29.07  29.39  11677478   BA  0.17
# 2   3816  2009-03-04  29.86  30.78  29.11  30.31  11627491   BA  0.45
# 3   3814  2009-03-02  30.96  31.00  29.32  29.51  13957450   BA -1.45
# 4   3818  2009-03-06  29.61  30.20  29.39  30.10  13134932   BA  0.49

# %%
Q4Stocks_max = Q4Stocks.sort_values(by='High',ascending=False).head(5).reset_index()
Q4Stocks_max
# Out:
#    index        Date    Open    High     Low   Close   Volume Name  Gain
# 0   6033  2017-12-20  298.70  299.33  297.11  297.90  2533689   BA -0.80
# 1   6034  2017-12-21  298.05  298.39  294.13  295.03  5398275   BA -3.02
# 2   6032  2017-12-19  296.50  297.58  294.18  297.25  2728367   BA  0.75
# 3   6036  2017-12-26  295.54  297.44  294.65  295.36  1394737   BA -0.18
# 4   6030  2017-12-15  295.87  297.37  293.02  293.94  6933490   BA -1.93

# %%
BA['Volume'] = BA['Volume']/10000000 
GS['Volume'] = GS['Volume']/10000000 
IBM['Volume'] = IBM['Volume']/10000000 
MMM['Volume'] = MMM['Volume']/10000000 
CVX['Volume'] = CVX['Volume']/10000000

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
GS.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
GS.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
IBM.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
IBM.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
MMM.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
MMM.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
BA.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
BA.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.52, 0.6, 0.4]) # inset axes

# Larger Figure Axes 1
CVX.plot(x='Date',y='Volume',ax=axes1,color="green")
axes1.set_xlabel('Date')
axes1.set_ylabel('Volume')
axes1.set_title('Volume')

# Insert Figure Axes 2
CVX.plot(x='Date',y='High',label='High',ax=axes2)
axes2.set_xlabel('Date')
axes2.set_ylabel('High')
axes2.set_title('High');

# %%
#basic stock Volume movement
fig,axes=plt.subplots(figsize=(30,8))
Q4Stocks[Q4Stocks['Name']=='GS'].plot(x='Date',y='Close',label='Amazon',ax=axes)
Q4Stocks[Q4Stocks['Name']=='IBM'].plot(x='Date',y='Close',label='IBM',ax=axes)
Q4Stocks[Q4Stocks['Name']=='MMM'].plot(x='Date',y='Close',label='3M',ax=axes)
Q4Stocks[Q4Stocks['Name']=='BA'].plot(x='Date',y='Close',label='Boeing',ax=axes)
Q4Stocks[Q4Stocks['Name']=='CVX'].plot(x='Date',y='Close',label='Chevron Corporation',ax=axes)
axes.set_ylabel("Close")
axes.set_title("Stock Close",fontsize=20)
# Out:
# Text(0.5,1,'Stock Close')

# %%
#basic stock Volume movement 
fig,axes=plt.subplots(figsize=(30,8))
Q4Stocks[Q4Stocks['Name']=='GS'].plot(x='Date',y='Volume',label='Goldman Sachs Group Inc',ax=axes)
Q4Stocks[Q4Stocks['Name']=='IBM'].plot(x='Date',y='Volume',label='IBM',ax=axes)
Q4Stocks[Q4Stocks['Name']=='MMM'].plot(x='Date',y='Volume',label='3M',ax=axes)
Q4Stocks[Q4Stocks['Name']=='BA'].plot(x='Date',y='Volume',label='Boeing',ax=axes)
Q4Stocks[Q4Stocks['Name']=='CVX'].plot(x='Date',y='Volume',label='Chevron Corporation',ax=axes)
axes.set_ylabel("Stock Volume")
axes.set_title("Stock volume movement",fontsize=20)
# Out:
# Text(0.5,1,'Stock volume movement')

# %%
#monthly closing price distribution

Q4Stocks['Month']=pd.to_datetime(allsnp['Date']).dt.month
plt.style.use('bmh')
fig,axes=plt.subplots(5,1,figsize=(25,15),sharex=True)

sns.boxplot(ax=axes[0],x='Month',y='Gain',data=Q4Stocks[Q4Stocks['Name']=='GS'],palette='husl')
sns.boxplot(ax=axes[1],x='Month',y='Gain',data=Q4Stocks[Q4Stocks['Name']=='IBM'],palette='husl')
sns.boxplot(ax=axes[2],x='Month',y='Gain',data=Q4Stocks[Q4Stocks['Name']=='MMM'],palette='husl')
sns.boxplot(ax=axes[3],x='Month',y='Gain',data=Q4Stocks[Q4Stocks['Name']=='BA'],palette='husl')
sns.boxplot(ax=axes[4],x='Month',y='Gain',data=Q4Stocks[Q4Stocks['Name']=='CVX'],palette='husl')


plt.suptitle("Gain Price Monthwise",fontsize=26)

axes[0].set_title('Goldman Sachs Group Inc',fontsize=18)
axes[1].set_title('IBM',fontsize=18)
axes[2].set_title('3M',fontsize=18)
axes[3].set_title('Boeing',fontsize=18)
axes[4].set_title('Chevron Corporation',fontsize=18)


axes[0].set_ylabel("Gain",fontsize=18)
axes[1].set_ylabel("Gain",fontsize=18)
axes[2].set_ylabel("Gain",fontsize=18)
axes[3].set_ylabel("Gain",fontsize=18)
axes[4].set_ylabel("Gain",fontsize=18)
# Out:
# Text(0,0.5,'Gain')

# %%
allsnp = pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv')

plt.style.use('bmh')
#moving average plot

Q4Stocks['20d']= Q4Stocks.groupby("Name")['High'].rolling(20).mean().reset_index(drop=True)
fig,axes=plt.subplots(1,5,figsize=(30,8))
Q4Stocks[Q4Stocks['Name']=='GS'].plot(x='Date',y='20d',label='Moving Average',ax=axes[0])
Q4Stocks[Q4Stocks['Name']=='IBM'].plot(x='Date',y='20d',label='Moving Average',ax=axes[1])
Q4Stocks[Q4Stocks['Name']=='MMM'].plot(x='Date',y='20d',label='Moving Average',ax=axes[2])
Q4Stocks[Q4Stocks['Name']=='BA'].plot(x='Date',y='20d',label='Moving Average',ax=axes[3])
Q4Stocks[Q4Stocks['Name']=='CVX'].plot(x='Date',y='20d',label='Moving Average',ax=axes[4])

plt.suptitle("Moving Average plot with 20 day window",fontsize=18)

axes[0].set_ylabel("Highest Price",fontsize=18)
axes[0].set_title('Goldman Sachs Group Inc',fontsize=18)
axes[1].set_title('IBM',fontsize=18)
axes[2].set_title('3M',fontsize=18)
axes[3].set_title('Boeing',fontsize=18)
axes[4].set_title('Chevron Corporation',fontsize=18)

#axes[2].set_title('JP Morgan',fontsize=18)
plt.tight_layout()
fig.subplots_adjust(top=0.8)
